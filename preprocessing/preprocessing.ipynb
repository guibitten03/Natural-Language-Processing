# %%
from preprocessing.preprocessing import DataPreProcessing
import pandas as pd

# %%
data = pd.read_csv('Data/sample_us.csv', sep='\t')
data.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     18778586   RDIJS7QYB6XNR  B00EDBY7X8       122952789
# 1          US     24769659  R36ED1U38IELG8  B00D7JFOPC       952062646
# 2          US     44331596   R1UE3RPRGCOLD  B002LHA74O       818126353
# 3          US     23310293  R298788GS6I901  B00ARPLCGY       261944918
# 4          US     38745832    RNX4EXOBBPN5  B00UZOPOFW       717410439
#
#                                        product_title product_category  \
# 0                         Monopoly Junior Board Game             Toys
# 1  56 Pieces of Wooden Train Track Compatible wit...             Toys
# 2         Super Jumbo Playing Cards by S&S Worldwide             Toys
# 3           Barbie Doll and Fashions Barbie Gift Set             Toys
# 4  Emazing Lights eLite Flow Glow Sticks - Spinni...             Toys
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# ...

# %%
texts = data['review_body'].reset_index()
texts.head()
# Out:
#    index                                        review_body
# 0      0                                       Excellent!!!
# 1      1  Great quality wooden track (better than some o...
# 2      2                  Cards are not as big as pictured.
# 3      3  my daughter loved it and i liked the price and...
# 4      4  Do not buy these! They break very fast I spun ...

# %%
texts.rename(columns={"review_body":"text"}, inplace=True)

# %%
texts.head()
# Out:
#    index                                               text
# 0      0                                       Excellent!!!
# 1      1  Great quality wooden track (better than some o...
# 2      2                  Cards are not as big as pictured.
# 3      3  my daughter loved it and i liked the price and...
# 4      4  Do not buy these! They break very fast I spun ...

# %%
pre_data = DataPreProcessing(texts)

# %%
texts = pre_data.get_preprocessed_data()
texts.head()
# Out:
#    index                                               text
# 0      0                               [Excellent, !, !, !]
# 1      1  [Great, quality, wooden, track, (, better, tha...
# 2      2        [Cards, are, not, as, big, as, pictured, .]
# 3      3  [my, daughter, loved, it, and, i, liked, the, ...
# 4      4  [Do, not, buy, these, !, They, break, very, fa...
